# %%
import pandas as pd
import numpy as np

data = {
    "Energy Source": ["Solar", "Wind", "Hydropower", "Geothermal", "Biomass", "Nuclear"],
    "Energy Consumption (MWh)": [1200, np.nan, 2900, np.nan, 2500, 3200],
    "Cost (Million $)": [200, 400, np.nan, 150,250,np.nan]
}
energy_df = pd.DataFrame(data)
print("original Energy Data with Missing Values")
energy_df.head()
# Out:
# original Energy Data with Missing Values
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0

# %%
energy_df.isnull().sum()
# Out:
# Energy Source               0
# Energy Consumption (MWh)    2
# Cost (Million $)            2
# dtype: int64

# %%
#remove rows with array missing value
cleaned_df = energy_df.dropna(axis=0)
print("\nEnergy Data after Removing Rows with Missing Values:")
cleaned_df.head()
# Out:
# Energy Data after Removing Rows with Missing Values:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 4       Biomass                    2500.0             250.0

# %%
energy_df["Energy Consumption (MWh)"].fillna(ec_m, inplace=True)
energy_df["Cost (Million $)"].fillna(c_m, inplace=True)

print("\nData After Imputing Missing Values with Mean:")
energy_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0

# %%
ec_m = energy_df["Energy Consumption (MWh)"].mean()
c_m = energy_df["Cost (Million $)"].mean()
print(f"\n The mean of the Energy Consumption:{ec_m} MWh")
print(f"\nTne mean of the Cost:{c_m} Million $")
energy_df["Energy Consumption (MWh)"].fillna(ec_m, inplace = True)
energy_df["Cost (Million $)"].fillna(c_m, inplace=True)
print("\nDta Imputing Missing Value with The mean Value")..
energy_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0

# %%
ec_m = energy_df["Energy Consumption (MWh)"].mean()
c_m = energy_df["Cost (Million $)"].mean()
print(f"\n The mean of the Energy Consumption:{ec_m} MWh")
print(f"\nTne mean of the Cost:{c_m} Million $")
energy_df["Energy Consumption (MWh)"].fillna(ec_m, inplace = True)
energy_df["Cost (Million $)"].fillna(c_m, inplace=True)
print("\nDta Imputing Missing Value with The mean Value")..
energy_df.head()
#redefine dataframe
energy_df=pd.DataFrame(data)

backward_filled_df=energy_df.bfill()
print("\n DATA after backward filling : ")
backward_filled_df.head()
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0

# %%
energy_df = pd.DataFrame(data)

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])

print("\nData After Normalization (Min-Max Scaling):")
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
energy_df = pd.DataFrame(data)

from sklearn.preprocessing import MinMaxScaler

# Normalize the 'Energy Consumption (MWh)' and 'Cost (Million $)'
scaler = MinMaxScaler()

energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])

print("\nData After Normalization (Min-Max Scaling):")
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]] = scaler.fit_transform(energy_df[["Energy Consumption (MWh)", "Cost (Million $)"]])

print("\nData After Normalization (Min-Max Scaling):")
print(energy_df)
# Out:
#   Energy Source  Energy Consumption (MWh)  Cost (Million $)
# 0         Solar                    1200.0             200.0
# 1          Wind                       NaN             400.0
# 2    Hydropower                    2900.0               NaN
# 3    Geothermal                       NaN             150.0
# 4       Biomass                    2500.0             250.0
# 5       Nuclear                    3200.0               NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-881d99f6d339> in <cell line: 0>()
# ----> 1 print(energy_encoded_df)
#
# NameError: name 'energy_encoded_df' is not defined

# %%
energy_encodeed_df=pd.get_dummies(energy_df, columns=["Energy Source"])
print("\ndata after one-hot encoding categorical variables::")
print(energy_encodeed_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7ee56b274e82> in <cell line: 0>()
# ----> 1 print(energy_encodeed_df)
#
# NameError: name 'energy_encodeed_df' is not defined
